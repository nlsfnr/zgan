# %%
import sys; sys.path.append('..')
import torch

import dirk

# %%
n = 4
r = 23
se = dirk.models.SpatialEncoding(n)
img = se(torch.zeros((1, 0, r, r)))
for i in range(n):
    dirk.utils.show_grid(img[:,i,:,:] / 2 + 0.5)
    dirk.utils.show_grid(img[:,n + i,:,:] / 2 + 0.5)
